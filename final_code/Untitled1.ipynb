# %%
import pickle
import subprocess
import os 
import re
import numpy as np
import pandas as pd
import plotly.express as px
from sklearn.cluster import AgglomerativeClustering
from collections import Counter

# %%
a_file = open("data.pkl", "rb")
output = pickle.load(a_file)
print(output)
a_file.close()
# Out:
# {'SAH': ['10mh_1', '1af7_1', '1aqi_1', '1bc5_1', '1boo_1', '1cbf_1', '1d2h_3', '1f3l_1', '1fjx_1', '1jqd_3', '1khh_2', '1kpg_8', '1kph_4', '1kr5_1', '1l3i_3', '1l9k_1', '1mht_1', '1mlv_2', '1mxi_1', '1nv9_1', '1orh_1', '1ori_1', '1ozv_2', '1p0y_3', '1p1b_1', '1p1c_2', '1p9p_1', '1qan_1', '1r00_1', '1r6a_2', '1ri3_1', '1rje_2', '1rjg_1', '1s4d_11', '1skm_1', '1sui_2', '1sus_3', '1ual_1', '1uam_1', '1v9a_2', '1vce_1', '1wng_1', '1wy7_2', '1wzn_1', '1x1b_1', '1x1c_1', '1x1d_1', '1yf3_1', '2a14_1', '2aot_3', '2bb3_2', '2bh2_1', '2bqz_1', '2br5_1', '2bzg_1', '2c7q_1', '2cww_2', '2cx8_2', '2dek_1', '2dsg_1', '2dsh_1', '2dsi_1', '2dv3_1', '2dv4_1', '2dv5_1', '2dv7_1', '2dxv_1', '2dxw_1', '2dxx_1', '2e07_1', '2e08_1', '2e0n_1', '2e15_1', '2e16_1', '2e17_1', '2e4n_1', '2e7r_1', '2e8h_1', '2e8q_1', '2e8r_1', '2e8s_1', '2ed3_1', '2ed5_1', '2eeq_1', '2eg5_4', '2egb_1', '2egl_1', '2egs_1', '2egw_2', '2eh2_1', '2eh4_1', '2eh5_1', '2ehl_1', '2ejj_1', '2ejk_1', '2eju_1', '2ejz_2', '2ek2_1', '2ek3_1'
# ...

# %%
len(output.keys())
# Out:
# 6890

# %%
output.keys()
# Out:
# dict_keys(['SAH', 'U2G', '0HH', 'SAS', 'GTX', 'BSP', 'CNA', 'EST', 'TFP', 'GSP', 'TET', 'BZU', 'NDP', 'DCF', 'GNH', 'QWE', 'NAD', 'FIP', 'COA', 'IGP', 'ATP', 'FMB', 'PAD', 'FKA', '2Z4', '0Q4', 'FAD', 'GTP', '061', 'U0E', '9DI', 'HPA', 'NOS', 'ADP', 'UPG', 'MGD', 'THA', 'ANP', 'CND', 'TAD', 'NAP', 'AZL', '0Z9', 'ALZ', 'TES', 'SU2', 'SBI', 'TOL', 'FMP', 'CHO', 'FMN', 'IPH', 'THK', 'CB3', 'PH2', 'SAN', '2PH', 'NMB', 'AH1', 'PLP', 'PPD', 'PPE', 'AP5', 'IMD', 'HST', 'DHP', 'GNP', '5GP', 'MTX', 'DDU', 'GW3', 'STU', 'RTL', '0HG', 'GTD', 'PDC', 'MAE', 'NPL', '0QI', 'AGS', 'AP2', 'BTN', 'TPP', 'INB', 'ALR', '3TL', 'NAE', 'NAQ', 'NDC', 'CYH', 'S27', 'HAG', 'GPS', 'DCM', 'MD2', 'PI5', 'PI4', 'PI6', 'PI7', 'OPE', 'FYA', 'ACO', 'IMG', 'IMH', 'IN7', 'PXG', 'PRL', 'URA', 'IM1', 'NAX', 'DUR', 'PCG', 'IPL', 'RDC', 'UMP', '0IU', '0QB', 'S80', 'ADE', 'ACV', 'FK5', 'AP1', 'SB6', 'SB4', 'SB5', 'AL5', 'AL6', 'AL9', 'TBU', 'AL8', 'AL1', 'AL4', 'AL2', 'AL3', 'AL7', 'TPD', 'GDP', 'PRD', 'N25', 'RBF', 'CAA', 
# ...

# %%
output
# Out:
# {'SAH': ['10mh_1',
#   '1af7_1',
#   '1aqi_1',
#   '1bc5_1',
#   '1boo_1',
#   '1cbf_1',
#   '1d2h_3',
#   '1f3l_1',
#   '1fjx_1',
#   '1jqd_3',
#   '1khh_2',
#   '1kpg_8',
#   '1kph_4',
#   '1kr5_1',
#   '1l3i_3',
#   '1l9k_1',
#   '1mht_1',
#   '1mlv_2',
#   '1mxi_1',
#   '1nv9_1',
#   '1orh_1',
#   '1ori_1',
#   '1ozv_2',
#   '1p0y_3',
#   '1p1b_1',
#   '1p1c_2',
#   '1p9p_1',
#   '1qan_1',
#   '1r00_1',
#   '1r6a_2',
#   '1ri3_1',
#   '1rje_2',
#   '1rjg_1',
#   '1s4d_11',
#   '1skm_1',
#   '1sui_2',
#   '1sus_3',
#   '1ual_1',
#   '1uam_1',
#   '1v9a_2',
#   '1vce_1',
#   '1wng_1',
#   '1wy7_2',
#   '1wzn_1',
#   '1x1b_1',
#   '1x1c_1',
#   '1x1d_1',
#   '1yf3_1',
#   '2a14_1',
#   '2aot_3',
#   '2bb3_2',
#   '2bh2_1',
#   '2bqz_1',
#   '2br5_1',
#   '2bzg_1',
#   '2c7q_1',
#   '2cww_2',
#   '2cx8_2',
#   '2dek_1',
#   '2dsg_1',
#   '2dsh_1',
#   '2dsi_1',
#   '2dv3_1',
#   '2dv4_1',
#   '2dv5_1',
#   '2dv7_1',
#   '2dxv_1',
#   '2dxw_1',
#   '2dxx_1',
#   '2e07_1',
# ...

# %%
new_dict1 = dict([(key, val) for key, val in 
           output.items() if len(val) > 300])

# %%
len(output)
# Out:
# 6890

# %%
len(new_dict1)
# Out:
# 7

# %%
new_dict1.keys()
# Out:
# dict_keys(['SAH', 'NAD', 'ATP', 'FAD', 'ADP', 'NAP', 'FMN'])

# %%
new_dict1
# Out:
# {'SAH': ['10mh_1',
#   '1af7_1',
#   '1aqi_1',
#   '1bc5_1',
#   '1boo_1',
#   '1cbf_1',
#   '1d2h_3',
#   '1f3l_1',
#   '1fjx_1',
#   '1jqd_3',
#   '1khh_2',
#   '1kpg_8',
#   '1kph_4',
#   '1kr5_1',
#   '1l3i_3',
#   '1l9k_1',
#   '1mht_1',
#   '1mlv_2',
#   '1mxi_1',
#   '1nv9_1',
#   '1orh_1',
#   '1ori_1',
#   '1ozv_2',
#   '1p0y_3',
#   '1p1b_1',
#   '1p1c_2',
#   '1p9p_1',
#   '1qan_1',
#   '1r00_1',
#   '1r6a_2',
#   '1ri3_1',
#   '1rje_2',
#   '1rjg_1',
#   '1s4d_11',
#   '1skm_1',
#   '1sui_2',
#   '1sus_3',
#   '1ual_1',
#   '1uam_1',
#   '1v9a_2',
#   '1vce_1',
#   '1wng_1',
#   '1wy7_2',
#   '1wzn_1',
#   '1x1b_1',
#   '1x1c_1',
#   '1x1d_1',
#   '1yf3_1',
#   '2a14_1',
#   '2aot_3',
#   '2bb3_2',
#   '2bh2_1',
#   '2bqz_1',
#   '2br5_1',
#   '2bzg_1',
#   '2c7q_1',
#   '2cww_2',
#   '2cx8_2',
#   '2dek_1',
#   '2dsg_1',
#   '2dsh_1',
#   '2dsi_1',
#   '2dv3_1',
#   '2dv4_1',
#   '2dv5_1',
#   '2dv7_1',
#   '2dxv_1',
#   '2dxw_1',
#   '2dxx_1',
#   '2e07_1',
# ...

# %%
pockets_needed
# Out:
# ['10mh_1',
#  '1af7_1',
#  '1aqi_1',
#  '1bc5_1',
#  '1boo_1',
#  '1cbf_1',
#  '1d2h_3',
#  '1f3l_1',
#  '1fjx_1',
#  '1jqd_3',
#  '1khh_2',
#  '1kpg_8',
#  '1kph_4',
#  '1kr5_1',
#  '1l3i_3',
#  '1l9k_1',
#  '1mht_1',
#  '1mlv_2',
#  '1mxi_1',
#  '1nv9_1',
#  '1orh_1',
#  '1ori_1',
#  '1ozv_2',
#  '1p0y_3',
#  '1p1b_1',
#  '1p1c_2',
#  '1p9p_1',
#  '1qan_1',
#  '1r00_1',
#  '1r6a_2',
#  '1ri3_1',
#  '1rje_2',
#  '1rjg_1',
#  '1s4d_11',
#  '1skm_1',
#  '1sui_2',
#  '1sus_3',
#  '1ual_1',
#  '1uam_1',
#  '1v9a_2',
#  '1vce_1',
#  '1wng_1',
#  '1wy7_2',
#  '1wzn_1',
#  '1x1b_1',
#  '1x1c_1',
#  '1x1d_1',
#  '1yf3_1',
#  '2a14_1',
#  '2aot_3',
#  '2bb3_2',
#  '2bh2_1',
#  '2bqz_1',
#  '2br5_1',
#  '2bzg_1',
#  '2c7q_1',
#  '2cww_2',
#  '2cx8_2',
#  '2dek_1',
#  '2dsg_1',
#  '2dsh_1',
#  '2dsi_1',
#  '2dv3_1',
#  '2dv4_1',
#  '2dv5_1',
#  '2dv7_1',
#  '2dxv_1',
#  '2dxw_1',
#  '2dxx_1',
#  '2e07_1',
#  '2e08_1',
#  '2e0n_1',
#  '2e15_1',
#  '2e16_1',
#  '2e17_1',
#  '2e4n_1',
# ...

# %%
data_csv = []
pockets_needed = []
counter = 0
for key in new_dict1:
    print(key)
    for value in new_dict1[key]:
        data_csv.append(str(value)+",0,"+str(counter))
        pockets_needed.append(value)
    counter += 1

pd_data = pd.DataFrame(data_csv)
pd_data.to_csv('data.csv',index=False)
# Out:
# SAH
# NAD
# ATP
# FAD
# ADP
# NAP
# FMN

# %%
pockets_needed[-1]
# Out:
# '5j4e_4'

# %%
len(pockets_needed)
# Out:
# 3636

# %%
pd_data
# Out:
#                0
# 0     10mh_1,0,0
# 1     1af7_1,0,0
# 2     1aqi_1,0,0
# 3     1bc5_1,0,0
# 4     1boo_1,0,0
# ...          ...
# 3631  5efw_1,0,6
# 3632  5f12_2,0,6
# 3633  5fx2_1,0,6
# 3634  5j3w_4,0,6
# 3635  5j4e_4,0,6
#
# [3636 rows x 1 columns]

# %%
e="adacadc_1.pdb"
print(e[:-3])
# Out:
# 'adacadc_1.'

# %%
import os
import shutil

source = "/home/user/Documents/algorithms_in_structural_biology/Final/pdb_all"
destination = "/home/user/Documents/algorithms_in_structural_biology/Final/pdb"

for root, subFolders, files in os.walk(source):
    for file in files:
        if file[:-4] in pockets_needed:
            shutil.move(source+"/"+str(file[:-4])+".pdb", destination+"/"+str(file[:-4])+".pdb")
#         subFolder = os.path.join(destpath, file[:6])
#         if not os.path.isdir(subFolder):
#             os.makedirs(subFolder)
            
#         shutil.move(os.path.join(root, file), subFolder)
